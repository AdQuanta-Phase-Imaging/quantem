# %%
from pathlib import Path
import numpy as np

import quantem as em
from quantem.core import config
from quantem.core.datastructures import Dataset4dstem
from quantem.diffractive_imaging.dataset_models import PtychographyDatasetRaster
# from quantem.diffractive_imaging.pftm import PFTM, PFTM_DIP
from quantem.core.visualization import show_2d

from quantem.core import config
from quantem.core.datastructures import Dataset4dstem
from quantem.core.visualization.visualization import show_2d
from quantem.diffractive_imaging.dataset_models import PtychographyDatasetRaster
from quantem.diffractive_imaging.detector_models import DetectorPixelated
from quantem.diffractive_imaging.object_models import ObjectDIP, ObjectPixelated
from quantem.diffractive_imaging.probe_models import ProbePixelated
from quantem.diffractive_imaging.ptychography import Ptychography
from quantem.core.utils.diffractive_imaging_utils import fit_probe_circle

config.set_device(0)
print(config.get("device"))
# Out:
# cuda:0

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import pickle

with open(r"./hbn_ptycho_datacubes_checkerboard.pkl", 'rb') as f:
    data = pickle.load(f)

merged_scan = data['merged_scan']
# merged_scan = data['dose_limited'][1e8]
scan_mask = data['scan_mask']
scan_sampling = data['scan_sampling']

# %%
# trying to extract two ptychography datasets from merged_scan according to scan_mask
# this is a checkerboard mask, and it is not trivial to extract two grids from it
# instead, we will refer to every 2x2 square as a unit cell, and average over the two datasets in each unit cell
# this will result in two datasets with half the number of scan points in each direction
target_shape = (merged_scan.shape[0] // 2, merged_scan.shape[1] // 2)

# %%
base_datacube = np.zeros(
    (
        target_shape[0], target_shape[1], 
        merged_scan.shape[2], merged_scan.shape[3]
    ), 
    dtype=merged_scan.dtype)
excited_datacube = np.zeros(
    (
        target_shape[0], target_shape[1], 
        merged_scan.shape[2], merged_scan.shape[3]
    ), 
    dtype=merged_scan.dtype)

for i in range(target_shape[0]):
    for j in range(target_shape[1]):
        unit_cell = merged_scan[2*i:2*i+2, 2*j:2*j+2, :, :]
        unit_cell_mask = scan_mask[2*i:2*i+2, 2*j:2*j+2]
        base_datacube[i, j, :, :] = np.mean(
            unit_cell[unit_cell_mask == 0, :, :], 
            axis=0
        )
        excited_datacube[i, j, :, :] = np.mean(
            unit_cell[unit_cell_mask == 1, :, :], 
            axis=0
        )

# %%
PROBE_ENERGY = 60e3
PROBE_SEMIANGLE = 20 # mrad 
PROBE_DEFOCUS = 30 # A 
SCAN_STEP_SIZE = 0.39285714285714285 # A 

NUM_PROBES = 1
NUM_SLICES = 1 
SLICE_THICKNESS = 1 # A

# %%
dset_base = Dataset4dstem.from_array(
    base_datacube,
    name='Base',
    sampling=(SCAN_STEP_SIZE, SCAN_STEP_SIZE, 1, 1),
    units=("A", "A", "pixels", "pixels")
)

dset_excited = Dataset4dstem.from_array(
    excited_datacube,
    name='Excited',
    sampling=(SCAN_STEP_SIZE, SCAN_STEP_SIZE, 1, 1),
    units=("A", "A", "pixels", "pixels")
)

# %%
import ptycho_wrappers, importlib
ptycho_wrappers = importlib.reload(ptycho_wrappers)
n_iters = 50
obj_padding = 32
tv = 1
ptycho_base = ptycho_wrappers.ptycho_wrapper(
    dset_base,
    tv_weight=tv,
    num_iters=n_iters,
    probe_energy=60e3,
    obj_padding=obj_padding,
)
ptycho_excited = ptycho_wrappers.ptycho_wrapper(
    dset_excited,
    tv_weight=tv,
    num_iters=n_iters,
    probe_energy=60e3,
    obj_padding=obj_padding,
)
# Out:
# cuda:0
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities:   0%|          | 0/784 [00:00<?, ?probe position/s]
#   0%|          | 0/50 [00:00<?, ?it/s]
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities:   0%|          | 0/784 [00:00<?, ?probe position/s]
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
ptycho_base.visualize()
ptycho_excited.visualize()

# %%
from visualizers import plot_image_diffs
phase_base = ptycho_base.obj_model.obj[0,...].cpu().angle().detach().numpy()
phase_excited = ptycho_excited.obj_model.obj[0,...].cpu().angle().detach().numpy()

# there are weird alignment issues introduced, I assume its due to the padding 
# and the funny way we extrapolated the data
plot_image_diffs(
    phase_base[17:-15, 17:-15], 
    phase_excited[16:-16, 16:-16]
)

# %%
dose_limited_recons = {
    'opt': (phase_base, phase_excited)
}

# %%
# do the same for all doses
for dose, merged_ds in data['dose_limited'].items():
    for i in range(merged_ds.shape[0]):
        for j in range(merged_ds.shape[1]):
            merged_ds[i,j,...] /= np.sum(np.abs(merged_ds[i,j,...]))
    # untangle datasets
    base_datacube = np.zeros(
        (
            target_shape[0], target_shape[1], 
            merged_ds.shape[2], merged_ds.shape[3]
        ), 
        dtype=merged_scan.dtype)
    excited_datacube = np.zeros(
        (
            target_shape[0], target_shape[1], 
            merged_ds.shape[2], merged_ds.shape[3]
        ), 
        dtype=merged_ds.dtype)

    for i in range(target_shape[0]):
        for j in range(target_shape[1]):
            unit_cell = merged_ds[2*i:2*i+2, 2*j:2*j+2, :, :]
            unit_cell_mask = scan_mask[2*i:2*i+2, 2*j:2*j+2]
            base_datacube[i, j, :, :] = np.mean(
                unit_cell[unit_cell_mask == 0, :, :], 
                axis=0
            )
            excited_datacube[i, j, :, :] = np.mean(
                unit_cell[unit_cell_mask == 1, :, :], 
                axis=0
            )

    dset_base = Dataset4dstem.from_array(
        base_datacube,
        name='Base',
        sampling=(SCAN_STEP_SIZE, SCAN_STEP_SIZE, 1, 1),
        units=("A", "A", "pixels", "pixels")
    )

    dset_excited = Dataset4dstem.from_array(
        excited_datacube,
        name='Excited',
        sampling=(SCAN_STEP_SIZE, SCAN_STEP_SIZE, 1, 1),
        units=("A", "A", "pixels", "pixels")
    )

    # run recons
    import ptycho_wrapper, importlib
    ptycho_wrapper = importlib.reload(ptycho_wrapper)
    tv = 1
    ptycho_base = ptycho_wrapper.ptycho_wrapper(
        dset_base,
        tv_weight=tv,
        num_iters=50,
        probe_energy=60e3,
        obj_padding=32,
    )
    ptycho_excited = ptycho_wrapper.ptycho_wrapper(
        dset_excited,
        tv_weight=tv,
        num_iters=50,
        probe_energy=60e3,
        obj_padding=32,
    )
    phase_base = ptycho_base.obj_model.obj[0,...].cpu().angle().detach().numpy()
    phase_excited = ptycho_excited.obj_model.obj[0,...].cpu().angle().detach().numpy()

    dose_limited_recons[f'{dose:.1e}'] = (phase_base, phase_excited)
    plot_image_diffs(
        phase_base[17:-15, 17:-15], 
        phase_excited[16:-16, 16:-16]
    )
    plt.show()
# Out:
# cuda:0
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 784/784 [00:01<00:00, 558.48probe position/s]
#   0%|          | 0/25 [00:00<?, ?it/s]/home/rotelimelech/differential_ptycho/quantem/src/quantem/diffractive_imaging/object_models.py:393: UserWarning: calculating TV loss for phase, need to check phase wrapping. Easiest fix is scalar phase array.
#   warn(
# Iter 25/25, Loss: 4.022e+01: 100%|██████████| 25/25 [00:03<00:00,  7.71it/s]
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 784/784 [00:01<00:00, 605.00probe position/s]
# Iter 25/25, Loss: 3.949e+01: 100%|██████████| 25/25 [00:03<00:00,  7.68it/s]
# cuda:0
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 784/784 [00:01<00:00, 592.10probe position/s]
# Iter 25/25, Loss: 4.560e+00: 100%|██████████| 25/25 [00:03<00:00,  7.25it/s]
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 784/784 [00:01<00:00, 548.61probe position/s]
# Iter 25/25, Loss: 4.647e+00: 100%|██████████| 25/25 [00:03<00:00,  7.44it/s]
# cuda:0
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 784/784 [00:01<00:00, 519.02probe position/s]
# Iter 25/25, Loss: 1.280e+00: 100%|██████████| 25/25 [00:03<00:00,  7.62it/s]
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 784/784 [00:01<00:00, 417.30probe position/s]
# Iter 25/25, Loss: 1.288e+00: 100%|██████████| 25/25 [00:03<00:00,  6.98it/s]
# cuda:0
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 784/784 [00:01<00:00, 575.47probe position/s]
# Iter 25/25, Loss: 5.041e-01: 100%|██████████| 25/25 [00:03<00:00,  7.60it/s]
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 784/784 [00:01<00:00, 493.83probe position/s]
# Iter 25/25, Loss: 4.947e-01: 100%|██████████| 25/25 [00:03<00:00,  7.69it/s]
# cuda:0
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 784/784 [00:01<00:00, 639.99probe position/s]
# Iter 25/25, Loss: 2.429e-01: 100%|██████████| 25/25 [00:03<00:00,  7.62it/s]
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 784/784 [00:01<00:00, 592.64probe position/s]
# Iter 25/25, Loss: 2.412e-01: 100%|██████████| 25/25 [00:03<00:00,  7.77it/s]

# %%
dose_limited_recons.keys()
# Out:
# dict_keys(['opt', '{dose:.1e}', '1.0e+04', '1.0e+05', '1.0e+06', '1.0e+07', '1.0e+08'])

# %%
for k in dose_limited_recons.keys():    
    a, b = dose_limited_recons[k]

# %%
import visualizers, importlib
selected_doses = ['opt', '1.0e+04', '1.0e+06', '1.0e+08']
visualizers = importlib.reload(visualizers)
visualizers.plot_dose_dependent_strip({i: dose_limited_recons[i] for i in selected_doses})

# %%
# now do the same by getting the datasets from skips
single_sample_ch = merged_scan[::2,::2, ...]
dset = Dataset4dstem.from_array(
    single_sample_ch,
    name='single_channel',
    sampling=(SCAN_STEP_SIZE, SCAN_STEP_SIZE, 1, 1),
    units=("A", "A", "pixels", "pixels")
)

ptycho_base = ptycho_wrapper.ptycho_wrapper(
    dset,
    tv_weight=1,
    num_iters=25,
    probe_energy=60e3,
    obj_padding=16,
)
# Out:
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 784/784 [00:01<00:00, 664.43probe position/s]
#   0%|          | 0/25 [00:00<?, ?it/s]/home/rotelimelech/differential_ptycho/quantem/src/quantem/diffractive_imaging/object_models.py:393: UserWarning: calculating TV loss for phase, need to check phase wrapping. Easiest fix is scalar phase array.
#   warn(
# Iter 25/25, Loss: 1.639e-01: 100%|██████████| 25/25 [00:03<00:00,  8.04it/s]

# %%
ptycho_base.visualize()

# %%
# now do the same by getting the datasets from skips
single_sample_ch = merged_scan[1::2,1::2, ...]
dset = Dataset4dstem.from_array(
    single_sample_ch,
    name='single_channel',
    sampling=(SCAN_STEP_SIZE, SCAN_STEP_SIZE, 1, 1),
    units=("A", "A", "pixels", "pixels")
)

ptycho_excited = ptycho_wrapper.ptycho_wrapper(
    dset_base,
    tv_weight=1,
    num_iters=25,
    probe_energy=60e3,
    obj_padding=16,
)

# %%
break
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
ptycho_base.obj_model.obj.shape
# Out:
# torch.Size([1, 120, 120])
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# create a pixelated ptychography first, to fit the dft basis to.
probe_params = {
    "energy" : PROBE_ENERGY,
    "defocus" : PROBE_DEFOCUS,
    "semiangle_cutoff" : PROBE_SEMIANGLE, 
}
detector_model = DetectorPixelated() 

# Set up ptychography model for excited state
probe_model = ProbePixelated.from_params(
    num_probes=1,
    probe_params=probe_params,
)

obj_model = ObjectPixelated.from_uniform(
    num_slices=1, 
    slice_thicknesses=1,
    obj_type='pure_phase',
)
probe_model = ProbePixelated.from_params(
    num_probes=1,
    probe_params=probe_params,
)
ptycho = Ptychography.from_models(
    dset=pdset_base,
    obj_model=obj_model,
    probe_model=probe_model,
    detector_model=detector_model,
    device='cpu',
)
ptycho.preprocess( 
    obj_padding_px=(16, 16),
    batch_size=16,
)
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
lr = 1e-1
obj_lr = lr
probe_lr = lr

opt_params = { # except type, all args are passed to the optimizer (of type type)
    "object": {
        "type": "adam", 
        "lr": obj_lr
        , 
    },
    "probe": {
        "type": "adam", 
        "lr": probe_lr, 
    },
    # "dataset": { ### for optimizing over descan shifts and probe positions
    #     "type": "adam",
    #     "lr": 1e-4,
    # }
}

scheduler_params = {
    "object": { ## scheduler kwargs are passed to the scheduler (of type type)
        "type": "exp",
        "factor": 0.1,
        # "type": "plateau", ## i like plateau for many cases
    },
    "probe": {
        # "type": "exp",
        "type": "plateau",
        # "threshold": 1e-2, # e.g. plateau kwargs 
        # "patience": 100,
        # "cooldown": 100,
    },
    # "dataset": { 
    #     "type": "exp",  ## exp is also frequently used 
    #     "factor": 0.1,
    # }
}

constraints = {
    "object": {
        "tv_weight_yx": 1e-3, ## these are mostly the defaults 
        "tv_weight_z": 0.,
        "fix_potential_baseline": False,
        "identical_slices": True, ## default for this is False 
        "apply_fov_mask": False,
    },
    "probe": {
        "center_probe": False,
        "orthogonalize_probe": True,
    },
    "dataset":{
        "descan_tv_weight": 0,
        "descan_shifts_constant": False, 
    }
}


# ptycho.remove_optimizer("probe")
ptycho.reconstruct(
    num_iters=50,
    reset=True,
    autograd=True, 
    device='cpu',
    constraints=constraints, 
    optimizer_params=opt_params,
    scheduler_params=scheduler_params,
    batch_size=16,
) # .visualize()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]C:\Users\rotem.eli\Documents\colin colab\quantum multiobj fork\quantem\src\quantem\diffractive_imaging\object_models.py:385: UserWarning: calculating TV loss for phase, need to check phase wrapping. Easiest fix is scalar phase array.
#   warn(
# Iter 50/50, Loss: 8.765e-01: 100%|██████████| 50/50 [00:29<00:00,  1.68it/s]
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
