# %%
from pathlib import Path
import numpy as np

import quantem as em
from quantem.core import config
from quantem.core.datastructures import Dataset4dstem
from quantem.diffractive_imaging.dataset_models import PtychographyDatasetRaster
# from quantem.diffractive_imaging.pftm import PFTM, PFTM_DIP
from quantem.core.visualization import show_2d

from quantem.core import config
from quantem.core.datastructures import Dataset4dstem
from quantem.core.visualization.visualization import show_2d
from quantem.diffractive_imaging.dataset_models import PtychographyDatasetRaster
from quantem.diffractive_imaging.detector_models import DetectorPixelated
from quantem.diffractive_imaging.object_models import ObjectDIP, ObjectPixelated
from quantem.diffractive_imaging.probe_models import ProbePixelated
from quantem.diffractive_imaging.ptychography import Ptychography
from quantem.core.utils.diffractive_imaging_utils import fit_probe_circle

config.set_device(0)
print(config.get("device"))
# Out:
# cuda:0

# %%
import pickle

with open(r"/home/rotelimelech/differential_ptycho/data/hbn_ptycho_datacubes_checkerboard.pkl", 'rb') as f:
    data = pickle.load(f)

data.keys()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pickle
#       2
# ----> 3 with open(r"/home/rotelimelech/differential_ptycho/data/hbn_ptycho_datacubes_checkerboard.pkl", 'rb') as f:
#       4     data = pickle.load(f)
#       5
#       6 data.keys()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/rotelimelech/differential_ptycho/data/hbn_ptycho_datacubes_checkerboard.pkl'

# %%
data['scan_sampling']
# Out:
# 0.2

# %%
PROBE_ENERGY = data['acc_voltage']
PROBE_SEMIANGLE = data['conv_angle_mrad']
PROBE_DEFOCUS = data['defocus_A']
# SCAN_STEP_SIZE = SCAN_STEP_SIZE # data['scan_sampling'] 

NUM_PROBES = 1
NUM_SLICES = 1 
SLICE_THICKNESS = 1 # A

# %%
SCAN_STEP_SIZE = 0.39285714285714285

# %%
merged_scan = data['merged_scan']
scan_mask = data['scan_mask']
scan_sampling = data['scan_sampling']

# %%
from matplotlib import pyplot as plt
plt.imshow(scan_mask)

# %% [markdown]
# # Sanity check - only take one object channel and run the algo to check for convergence

# %%
single_sample_ch = merged_scan[::2,::2, ...]
scan_mask_single_ch = scan_mask[::2,::2, ...].copy()
print(single_sample_ch.shape, merged_scan.shape)
print(np.all(scan_mask_single_ch == 1)) # show that it is indeed a single channel
scan_mask_single_ch[:,:] = 0  # since we only have one channel, make sure that the mask choices only that channel
# Out:
# (28, 28, 128, 128) (56, 56, 128, 128)
# True

# %%
SCAN_STEP_SIZE
# Out:
# 0.39285714285714285

# %%
dset = Dataset4dstem.from_array(
    single_sample_ch,
    name='single_channel',
    sampling=(SCAN_STEP_SIZE, SCAN_STEP_SIZE, 1, 1),
    units=("A", "A", "pixels", "pixels")
)

# %%
PROBE_DEFOCUS, PROBE_ENERGY, PROBE_SEMIANGLE
# Out:
# (30, 60000.0, 20)

# %%
probe_qy0, probe_qx0, probe_R = fit_probe_circle(dset.dp_mean.array, show=False)
dset.sampling[2] = PROBE_SEMIANGLE / probe_R
dset.sampling[3] = PROBE_SEMIANGLE / probe_R
dset.units[2:] = ["mrad", "mrad"]
probe_R = PROBE_SEMIANGLE / dset.sampling[2]
# print(dset)

pdset = PtychographyDatasetRaster.from_dataset4dstem(dset)
pdset.preprocess(
    com_fit_function="constant",
    plot_rotation=False,
    plot_com=True,
    probe_energy=PROBE_ENERGY,
    force_com_rotation=0, 
    force_com_transpose=False,
)    

probe_params = {
    "energy" : PROBE_ENERGY,
    "defocus" : PROBE_DEFOCUS,
    "semiangle_cutoff" : PROBE_SEMIANGLE, 
}
detector_model = DetectorPixelated() 

# Set up ptychography model for excited state
probe_model = ProbePixelated.from_params(
    num_probes=1,
    probe_params=probe_params,
)
# Out:
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities:   0%|          | 0/784 [00:00<?, ?probe position/s]

# %%
import torch
from quantem.diffractive_imaging.object_models import ObjectMultiplexed
import importlib
import quantem.diffractive_imaging.object_models as om

importlib.reload(om)
from quantem.diffractive_imaging.object_models import ObjectMultiplexed

obj_model = ObjectMultiplexed.from_uniform(
    num_slices=NUM_SLICES, 
    slice_thicknesses=SLICE_THICKNESS,
    obj_type='pure_phase',
    num_channels=1,
    patches_mask=torch.tensor(scan_mask_single_ch)
)

# %%
ptycho = Ptychography.from_models(
    dset=pdset,
    obj_model=obj_model,
    probe_model=probe_model,
    detector_model=detector_model,
    device='cuda',
)

ptycho.preprocess( 
    obj_padding_px=(16, 16),
    batch_size=128,
)
# Out:
# /home/rotelimelech/differential_ptycho/quantem/src/quantem/diffractive_imaging/object_models.py:1279: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at /pytorch/aten/src/ATen/native/Copy.cpp:309.)
#   post_constraint_obj[ch] = self.apply_hard_constraints(

# %%
lr = 1e-2
obj_lr = 1e-1
probe_lr = 1e-3
tv_weight = 0.1

opt_params = { # except type, all args are passed to the optimizer (of type type)
    "object": {
        "type": "adam", 
        "lr": obj_lr
        , 
    },
    "probe": {
        "type": "adam", 
        "lr": probe_lr, 
    },
    # "dataset": { ### for optimizing over descan shifts and probe positions
    #     "type": "adam",
    #     "lr": 1e-4,
    # }
}

scheduler_params = {
    "object": { ## scheduler kwargs are passed to the scheduler (of type type)
        # "type": "exp",
        # "factor": 0.1,
        "type": "plateau", ## i like plateau for many cases
    },
    "probe": {
        # "type": "exp",
        "type": "plateau",
        # "threshold": 1e-2, # e.g. plateau kwargs 
        # "patience": 100,
        "cooldown": 100,
    },
    # "dataset": { 
    #     "type": "exp",  ## exp is also frequently used 
    #     "factor": 0.1,
    # }
}

constraints = {
    "object": {
        "tv_weight_xy": tv_weight, ## these are mostly the defaults 
        # "tv_weight_z": 0.,
        "fix_potential_baseline": False,
        "identical_slices": True, ## default for this is False 
        "apply_fov_mask": False,
    },
    "probe": {
        "center_probe": False,
        "orthogonalize_probe": True,
    },
    "dataset":{
        "descan_tv_weight": 0,
        "descan_shifts_constant": False, 
    }
}

# %%
ptycho.reconstruct(
    num_iters=10,
    reset=True,
    autograd=True, 
    device='cuda',
    constraints=constraints, 
    optimizer_params=opt_params,
    scheduler_params=scheduler_params,
    batch_size=64,
    multichannel_mode=True,
) # .visualize()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# /home/rotelimelech/differential_ptycho/quantem/src/quantem/diffractive_imaging/object_models.py:393: UserWarning: calculating TV loss for phase, need to check phase wrapping. Easiest fix is scalar phase array.
#   warn(
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# /home/rotelimelech/differential_ptycho/quantem/src/quantem/diffractive_imaging/object_models.py:393: UserWarning: calculating TV loss for phase, need to check phase wrapping. Easiest fix is scalar phase array.
#   warn(
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# Something broke!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 ptycho.reconstruct(
#       2     num_iters=10,
#       3     reset=True,
#       4     autograd=True,
#       5     device='cuda',
#       6     constraints=constraints,
#       7     optimizer_params=opt_params,
#       8     scheduler_params=scheduler_params,
#       9     batch_size=64,
#      10     multichannel_mode=True,
#      11 ) # .visualize()
#
# File ~/differential_ptycho/quantem/src/quantem/diffractive_imaging/ptychography.py:221, in Ptychography.reconstruct(self, num_iters, reset, optimizer_params, scheduler_params, constraints, batch_size, store_snapshots, store_snapshots_every, device, autograd, loss_type, multichannel_mode)
#     219 shifted_probes = self.probe_model.forward(positions_px_fractional)
#     220 if multichannel_mode:
# --> 221     obj_patches = self.obj_model.forward(patch_indices, batch_indices)
#     222 else:
#     223     obj_patches = self.obj_model.forward(patch_indices)
#
# File ~/differential_ptycho/quantem/src/quantem/diffractive_imaging/object_models.py:1412, in ObjectMultiplexed.forward(self, patch_indices, batch_indices)
#    1410 ch_batch_mask = batch_elem_to_ch == ch
#    1411 ch_patches_ids = patch_indices[ch_batch_mask,...]
# -> 1412 ch_patches = self._get_obj_patches(self.obj[ch,...], ch_patches_ids)
#    1413 # ch_patches = ch_patches.transpose(0,1) # [batch elem, z, y, x]
#    1414 out[:,ch_batch_mask,...] = ch_patches
#
# File ~/differential_ptycho/quantem/src/quantem/diffractive_imaging/object_models.py:1274, in ObjectMultiplexed.obj(self)
#    1270     self._obj = nn.Parameter(torch.ones(num_channels, num_slices, 1, 1), requires_grad=True)
#    1272     self.patches_mask = patches_mask.reshape(-1)
# -> 1274 @property
#    1275 def obj(self):
#    1276     # applying the hard containts to each channel separately
#    1277     post_constraint_obj = torch.zeros_like(self._obj)
#    1278     for ch in range(self._obj.shape[0]):
#
# KeyboardInterrupt:

# %%
ptycho.plot_losses()

# %%
from matplotlib import pyplot as plt
recon_phase = ptycho.obj_model.obj[0,0,...].angle().detach().cpu().numpy()
plt.imshow(recon_phase[16:-16,16:-16])
plt.colorbar()
plt.title("Reconstructed Phase")
plt.show()

# %%
ptycho.show_probe()

# %% [markdown]
# # Multichannel recon

# %%
dset = Dataset4dstem.from_array(
    merged_scan,
    name='merged_scan',
    sampling=(SCAN_STEP_SIZE/2, SCAN_STEP_SIZE/2, 1, 1),
    units=("A", "A", "pixels", "pixels")
)

# %%
probe_qy0, probe_qx0, probe_R = fit_probe_circle(dset.dp_mean.array, show=False)
dset.sampling[2] = PROBE_SEMIANGLE / probe_R
dset.sampling[3] = PROBE_SEMIANGLE / probe_R
dset.units[2:] = ["mrad", "mrad"]
probe_R = PROBE_SEMIANGLE / dset.sampling[2]
# print(dset)


pdset = PtychographyDatasetRaster.from_dataset4dstem(dset)
pdset.preprocess(
    com_fit_function="constant",
    plot_rotation=False,
    plot_com=False,
    probe_energy=PROBE_ENERGY,
    force_com_rotation=0, 
    force_com_transpose=False,
)    

probe_params = {
    "energy" : PROBE_ENERGY,
    "defocus" : PROBE_DEFOCUS,
    "semiangle_cutoff" : PROBE_SEMIANGLE, 
}
detector_model = DetectorPixelated() 

# Set up ptychography model for excited state
probe_model = ProbePixelated.from_params(
    num_probes=1,
    probe_params=probe_params,
)
# Out:
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 3136/3136 [00:04<00:00, 676.53probe position/s]

# %%
import torch
from quantem.diffractive_imaging.object_models import ObjectMultiplexed
import importlib
import quantem.diffractive_imaging.object_models as om

importlib.reload(om)
from quantem.diffractive_imaging.object_models import ObjectMultiplexed

obj_model = ObjectMultiplexed.from_uniform(
    num_slices=NUM_SLICES, 
    slice_thicknesses=SLICE_THICKNESS,
    obj_type='pure_phase',
    num_channels=2,
    patches_mask=torch.tensor(scan_mask)
)

# %%
ptycho = Ptychography.from_models(
    dset=pdset,
    obj_model=obj_model,
    probe_model=probe_model,
    detector_model=detector_model,
    device='cuda',
)

ptycho.preprocess( 
    obj_padding_px=(16, 16),
    batch_size=32,
)

# %%
lr = 1e-2
obj_lr = 1e-3
probe_lr = 1e-4
tv_weight = 1
tv_channel_diff = 10

opt_params = { # except type, all args are passed to the optimizer (of type type)
    "object": {
        "type": "adam", 
        "lr": obj_lr
        , 
    },
    "probe": {
        "type": "adam", 
        "lr": probe_lr, 
    },
    # "dataset": { ### for optimizing over descan shifts and probe positions
    #     "type": "adam",
    #     "lr": 1e-4,
    # }
}

scheduler_params = {
    "object": { ## scheduler kwargs are passed to the scheduler (of type type)
        "type": "exp",
        "factor": 9e-2,
        # "type": "plateau", ## i like plateau for many cases
    },
    "probe": {
        # "type": "exp",
        "type": "plateau",
        # "threshold": 1e-2, # e.g. plateau kwargs 
        # "patience": 100,
        # "cooldown": 100,
    },
    # "dataset": { 
    #     "type": "exp",  ## exp is also frequently used 
    #     "factor": 0.1,
    # }
}

constraints = {
    "object": {
        "tv_weight_xy": tv_weight, ## these are mostly the defaults 
        # "tv_weight_z": 0.,
        "fix_potential_baseline": False,
        "identical_slices": True, ## default for this is False 
        "apply_fov_mask": False,
        "tv_channel_diff": tv_channel_diff
    },
    "probe": {
        "center_probe": False,
        "orthogonalize_probe": True,
    },
    "dataset":{
        "descan_tv_weight": 0,
        "descan_shifts_constant": False, 
    }
}

# %%
ptycho.reconstruct(
    num_iters=25,
    reset=True,
    autograd=True, 
    device='cuda',
    constraints=constraints, 
    optimizer_params=opt_params,
    scheduler_params=scheduler_params,
    batch_size=128,
    multichannel_mode=True,
) # .visualize()
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# /home/rotelimelech/differential_ptycho/quantem/src/quantem/diffractive_imaging/object_models.py:393: UserWarning: calculating TV loss for phase, need to check phase wrapping. Easiest fix is scalar phase array.
#   warn(
# /home/rotelimelech/differential_ptycho/quantem/src/quantem/diffractive_imaging/object_models.py:393: UserWarning: calculating TV loss for phase, need to check phase wrapping. Easiest fix is scalar phase array.
#   warn(
# /home/rotelimelech/differential_ptycho/quantem/src/quantem/diffractive_imaging/object_models.py:393: UserWarning: calculating TV loss for phase, need to check phase wrapping. Easiest fix is scalar phase array.
#   warn(
# Iter 25/25, Loss: 5.792e-01: 100%|██████████| 25/25 [02:39<00:00,  6.37s/it]

# %%
ptycho.plot_losses()
recon_off = np.angle(ptycho.obj_model.obj[0,0,...].cpu().detach().cpu().numpy())
recon_on = np.angle(ptycho.obj_model.obj[1,0,...].cpu().detach().cpu().numpy())

from visualizers import plot_image_diffs
plot_image_diffs(recon_off[16:-16,16:-16], recon_on[16:-16,16:-16])

# %%
dose_limited_recons['opt'] = (recon_off, recon_on)

# %%
ptycho.obj_model._soft_constraint_loss
# Out:
# {'tv_loss': tensor(0.0033, device='cuda:0'),
#  'surface_zero_loss': tensor(0., device='cuda:0'),
#  'tv_channel_diff': tensor(0.0007, device='cuda:0')}

# %% [markdown]
# # Dose limited statistics

# %%
# redo for different doses
dose_limited_recons = {
    'opt': (recon_off, recon_on)
}
for dose, merged_scan in data['dose_limited'].items():
    # if dose != 10000:
    #     continue
    if dose > 2e6:
        continue
    print(dose)
    for i in range(merged_scan.shape[0]):
        for j in range(merged_scan.shape[1]):
            merged_scan[i,j,...] /= np.sum(np.abs(merged_scan[i,j,...]))

    dset = Dataset4dstem.from_array(
        merged_scan,
        name='merged_scan',
        sampling=(SCAN_STEP_SIZE/2, SCAN_STEP_SIZE/2, 1, 1),
        units=("A", "A", "pixels", "pixels")
    )
    probe_qy0, probe_qx0, probe_R = fit_probe_circle(dset.dp_mean.array, show=False)
    dset.sampling[2] = PROBE_SEMIANGLE / probe_R
    dset.sampling[3] = PROBE_SEMIANGLE / probe_R
    dset.units[2:] = ["mrad", "mrad"]
    probe_R = PROBE_SEMIANGLE / dset.sampling[2]
    # print(dset)


    pdset = PtychographyDatasetRaster.from_dataset4dstem(dset)
    pdset.preprocess(
        com_fit_function="constant",
        plot_rotation=False,
        plot_com=False,
        probe_energy=PROBE_ENERGY,
        force_com_rotation=0, 
        force_com_transpose=False,
    )    

    probe_params = {
        "energy" : PROBE_ENERGY,
        "defocus" : PROBE_DEFOCUS,
        "semiangle_cutoff" : PROBE_SEMIANGLE, 
    }
    detector_model = DetectorPixelated() 

    # Set up ptychography model for excited state
    probe_model = ProbePixelated.from_params(
        num_probes=1,
        probe_params=probe_params,
    )
    obj_model = ObjectMultiplexed.from_uniform(
        num_slices=NUM_SLICES, 
        slice_thicknesses=SLICE_THICKNESS,
        obj_type='pure_phase',
        num_channels=2,
        patches_mask=torch.tensor(scan_mask)
    )

    ptycho = Ptychography.from_models(
        dset=pdset,
        obj_model=obj_model,
        probe_model=probe_model,
        detector_model=detector_model,
        device='cuda',
    )

    ptycho.preprocess( 
        obj_padding_px=(16, 16),
        batch_size=32,
    )

    ptycho.reconstruct(
        num_iters=25,
        reset=True,
        autograd=True, 
        device='cuda',
        constraints=constraints, 
        optimizer_params=opt_params,
        scheduler_params=scheduler_params,
        batch_size=128,
        multichannel_mode=True,
    ) # .visualize()

    recon_off = np.angle(ptycho.obj_model.obj[0,0,...].cpu().detach().cpu().numpy())
    recon_on = np.angle(ptycho.obj_model.obj[1,0,...].cpu().detach().cpu().numpy())

    from visualizers import plot_image_diffs
    plot_image_diffs(recon_off[16:-16,16:-16], recon_on[16:-16,16:-16])
    plt.show()

    dose_limited_recons[f'{dose:.1e}'] = (recon_off, recon_on)
# Out:
# 10000
# Forcing best fit rotation to 0 degrees.
# Forcing transpose of intensities to False.
# Normalizing intensities: 100%|██████████| 3136/3136 [00:04<00:00, 694.27probe position/s]
# Iter 25/25, Loss: 3.446e+02: 100%|██████████| 25/25 [02:25<00:00,  5.81s/it]

# %%
import visualizers, importlib
selected_doses = ['1.0e+04', '1.0e+05', '1.0e+06', 'opt']
visualizers = importlib.reload(visualizers)
visualizers.plot_dose_dependent_strip({i: dose_limited_recons[i] for i in selected_doses})

# %%
ptycho.show_probe()

# %%
# scan for best lrs 
def do_ptycho(obj_lr, probe_lr):
    opt_params = { # except type, all args are passed to the optimizer (of type type)
        "object": {
            "type": "adam", 
            "lr": obj_lr
            , 
        },
        "probe": {
            "type": "adam", 
            "lr": probe_lr, 
        },
    }

    ptycho.reconstruct(
        num_iters=5,
        reset=True,
        autograd=True, 
        device='cuda',
        constraints=constraints, 
        optimizer_params=opt_params,
        scheduler_params=scheduler_params,
        batch_size=16,
    ) # .visualize()
    return ptycho.iter_losses

for obj_lr in np.logspace(-2, -7, 6):
    for probe_lr in np.logspace(-2, -7, 6):
        losses = do_ptycho(obj_lr, probe_lr)
        print(f"obj_lr: {obj_lr:.1e}, probe_lr: {probe_lr:.1e}, final loss: {losses[-1]:.4f}")
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# Iter 5/5, Loss: 1.346e+01: 100%|██████████| 5/5 [00:35<00:00,  7.17s/it]
# obj_lr: 1.0e-02, probe_lr: 1.0e-02, final loss: 13.4567
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 29
#      27 for obj_lr in np.logspace(-2, -7, 6):
#      28     for probe_lr in np.logspace(-2, -7, 6):
# ---> 29         losses = do_ptycho(obj_lr, probe_lr)
#      30         print(f"obj_lr: {obj_lr:.1e}, probe_lr: {probe_lr:.1e}, final loss: {losses[-1]:.4f}")
#
# Cell In[57], line 15, in do_ptycho(obj_lr, probe_lr)
#       2 def do_ptycho(obj_lr, probe_lr):
#       3     opt_params = { # except type, all args are passed to the optimizer (of type type)
#       4         "object": {
#       5             "type": "adam",
#    (...)     12         },
#      13     }
# ---> 15     ptycho.reconstruct(
#      16         num_iters=5,
#      17         reset=True,
#      18         autograd=True,
#      19         device='cuda',
#      20         constraints=constraints,
#      21         optimizer_params=opt_params,
#      22         scheduler_params=scheduler_params,
#      23         batch_size=16,
#      24     ) # .visualize()
#      25     return ptycho.iter_losses
#
# File ~/differential_ptycho/quantem/src/quantem/diffractive_imaging/ptychography.py:218, in Ptychography.reconstruct(self, num_iters, reset, optimizer_params, scheduler_params, constraints, batch_size, store_snapshots, store_snapshots_every, device, autograd, loss_type)
#     214 self.zero_grad_all()
#     215 patch_indices, _positions_px, positions_px_fractional, descan_shifts = (
#     216     self.dset.forward(batch_indices, self.obj_padding_px)
#     217 )
# --> 218 shifted_probes = self.probe_model.forward(positions_px_fractional)
#     219 # obj_patches = self.obj_model.forward(patch_indices)
#     220 obj_patches = self.obj_model.forward(patch_indices, batch_indices)
#
# File ~/differential_ptycho/quantem/src/quantem/diffractive_imaging/probe_models.py:719, in ProbePixelated.forward(self, fract_positions)
#     718 def forward(self, fract_positions: torch.Tensor) -> torch.Tensor:
# --> 719     shifted_probes = fourier_shift_expand(self.probe, fract_positions).swapaxes(0, 1)
#     720     return shifted_probes
#
# File ~/differential_ptycho/quantem/src/quantem/diffractive_imaging/ptycho_utils.py:132, in fourier_shift_expand(array, positions, expand_dim)
#     128 def fourier_shift_expand(
#     129     array: ArrayLike, positions: ArrayLike, expand_dim: bool = True
#     130 ) -> ArrayLike:
#     131     """Fourier-shift array by flat array of positions."""
# --> 132     phase = fourier_translation_operator(positions, array.shape, expand_dim, dtype=array.dtype)
#     133     fourier_array = af.fft2(array)
#     134     shifted_fourier_array = fourier_array * phase
#
# File ~/differential_ptycho/quantem/src/quantem/diffractive_imaging/ptycho_utils.py:175, in fourier_translation_operator(positions, shape, expand_dim, dtype)
#     173         ramp = ramp[:, None, ...]
#     174 if dtype is not None:
# --> 175     ramp = af.as_type(ramp, dtype)
#     176 return ramp
#
# File ~/differential_ptycho/quantem/src/quantem/core/utils/array_funcs.py:305, in as_type(a, dtype)
#     303 @overload
#     304 def as_type(a: "torch.Tensor", dtype: "type|str|torch.dtype") -> "torch.Tensor": ...
# --> 305 def as_type(a: ArrayLike, dtype: "type|str|torch.dtype") -> ArrayLike:
#     306     """Cast the array to a specified type."""
#     307     if config.get("has_torch"):
#
# KeyboardInterrupt:

# %%
# Out:
# array([1.e-02, 1.e-03, 1.e-04, 1.e-05, 1.e-06, 1.e-07])
